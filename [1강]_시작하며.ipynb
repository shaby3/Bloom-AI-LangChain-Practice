# %% [markdown]
# ## 기초 사용법

# %% [markdown]
# https://platform.openai.com/docs/quickstart?language=python

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-2.31.0-py3-none-any.whl.metadata (31 kB)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.14.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\sdm38\bloom-ai-langchain-practice\venv\lib\site-packages (from openai) (4.15.0)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openai)
#   Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\sdm38\bloom-ai-langchain-practice\venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-2.31.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.1/1.2 MB 2.9 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.2 MB 3.5 MB/s eta 0:00:01
#    --------------- ------------------------ 0.4/1.2 MB 3.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.6/1.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.8/1.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  1.1/1.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 3.5 MB/s eta 0:00:00
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.14.0-cp311-cp311-win_amd64.whl (204 kB)
#    ---------------------------------------- 0.0/204.7 kB ? eta -:--:--
#    ---------------------- ----------------- 112.6/204.7 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 204.7/204.7 kB 3.1 MB/s eta 0:00:00
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: typing-inspection, tqdm, sniffio, pydantic-core, jiter, idna, h11, distro, certifi, annotated-types, pydantic, httpcore, anyio, httpx, openai
# Successfully installed annotated-types-0.7.0 anyio-4.13.0 certifi-2026.2.25 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jiter-0.14.0 openai-2.31.0 pydantic-2.12.5 pydantic-core-2.41.5 sniffio-1.3.1 tqdm-4.67.3 typing-inspection-0.4.2
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-4o",
    input="Agent가 뭔가요?"
)

print(response.output_text)
# Out:
# "Agent"라는 용어는 문맥에 따라 다양한 의미를 가질 수 있습니다. 몇 가지 일반적인 의미를 설명드리겠습니다.
#
# 1. **소프트웨어 에이전트**: 특정 작업을 자동화하거나 수행하는 프로그램입니다. 예를 들어, 검색 엔진 봇이나 이메일 필터링 시스템 등이 이에 해당합니다.
#
# 2. **인공지능 에이전트**: 인공지능 분야에서는 환경을 인식하고 적절한 행동을 실행하여 목표를 달성하는 시스템을 의미합니다. 예를 들어, 자율주행차의 AI 시스템이 여기에 해당할 수 있습니다.
#
# 3. **비즈니스 에이전트**: 상업적인 거래나 계약을 대신 처리하는 사람이나 회사를 가리킵니다. 예를 들어, 부동산 에이전트나 스포츠 에이전트가 있습니다.
#
# 각 맥락에 따라 의미가 다르므로 구체적인 사용 사례를 고려해야 합니다.

# %%
print(response.output_text)

# %% [markdown]
# ## Reasoning

# %% [markdown]
# https://platform.openai.com/docs/guides/text

# %%
prompt = """
앵무새의 털 색상이 여러개인 이유가 뭐야?
"""

response = client.responses.create(
    model="gpt-5-nano",
    reasoning={"effort": "medium"},
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output_text)
# Out:
# 앵무새의 털 색이 여러 개인 이유는 크게 두 가지 색 생성 방식이 섞여 있기 때문이야.
#
# 1) 색소로 만든 색
# - 멜라닌: 검은색이나 갈색 계열.
# - 카로티노이드: 노랑, 주황, 빨강 등의 색을 만들어. 식단에서 얻어야 해서 건강과 먹이가 색상에 영향을 줘.
# - psittacofulvins: 앵무새만 가지는 특이한 색소로 빨강·핑크·보라 같은 색을 낳아. 종마다 다르지.
# - 한 깃털에 여러 색소가 섞여 보이기도 해.
#
# 2) 구조색으로 만든 색
# - 파랑이나 초록 같은 색은 실제로 색소가 아닌 미세한 깃털 구조에서 빛이 간섭·산란되어 생겨.
# - 파란 색은 주로 구조색으로, 녹색은 파란 구조색에 노란 색소(또는 노란 광택)가 더해져 보이는 경우가 많아.
# - 각도에 따라 색이 달라 보이거나 반짝이는 듯한 광택이 나는 경우도 있어.
#
# 왜 한 마리의 앵무새에서 여러 색이 보일까?
# - 몸의 여러 부위가 서로 다른 깃털 구조나 색소를 가지고 있기 때문이야. 예를 들어 몸은 초록(파란 구조색 + 노란 색소), 날개는 빨강이나 파랑처럼 다른 색을 낼 수 있어.
# - 색은 짝짓기나 사회적 신호로도 쓰이고, 건강 상태나 식단에 따라 색의 선명도가 달라지기도 해.
#
# 궁금한 특정 앵무새 종이 있으면 말해줘. 그 종의 색이 어떻게 다 만들어지는지 좀 더 구체적으로 설명해줄게.
